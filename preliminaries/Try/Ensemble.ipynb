# %%
import pandas as pd

# %%
decision_gap = pd.read_csv('/content/drive/MyDrive/LGaimers/input/decision_gap==0.002.csv')
score77 = pd.read_csv('/content/drive/MyDrive/LGaimers/input/score-0.77.csv')

# %%
result = decision_gap.copy()
result2 = score77.copy()

# %%
result2 = result2[result2['Y_Class']==2]
result2
# Out:
#     PRODUCT_ID  Y_Class
# 38    TEST_038        2
# 78    TEST_078        2
# 160   TEST_160        2
# 161   TEST_161        2
# 163   TEST_163        2
# 169   TEST_169        2
# 183   TEST_183        2
# 187   TEST_187        2

# %%
result[result['Y_Class']==2]
# Out:
#     PRODUCT_ID  Y_Class
# 38    TEST_038        2
# 78    TEST_078        2
# 160   TEST_160        2
# 161   TEST_161        2
# 163   TEST_163        2
# 183   TEST_183        2

# %%
under_index = score77[score77['Y_Class']==0].index
over_index = score77[score77['Y_Class']==2].index

result.loc[under_index, 'Y_Class'] = 0
result.loc[over_index, 'Y_Class'] = 2
result[result['Y_Class']==2]
# Out:
#     PRODUCT_ID  Y_Class
# 38    TEST_038        2
# 78    TEST_078        2
# 160   TEST_160        2
# 161   TEST_161        2
# 163   TEST_163        2
# 169   TEST_169        2
# 183   TEST_183        2
# 187   TEST_187        2

# %%
result['Y_Class'].value_counts()
# Out:
# 1    255
# 0     47
# 2      8
# Name: Y_Class, dtype: int64

# %%
result.to_csv('ensemble.csv',index=False)

# %%
from collections import Counter
Counter(result['Y_Class'] != score77['Y_Class'])
# Out:
# Counter({False: 303, True: 7})
